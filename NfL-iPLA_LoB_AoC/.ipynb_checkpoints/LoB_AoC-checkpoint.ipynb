# %%
import sys
from pathlib import Path
from scipy.optimize import curve_fit
from typing import Literal, Dict, Any

module_dir = Path.cwd().parent
sys.path.append(str(module_dir))

from ProxiPal import *
# Out:
# OS:				 Windows-11-10.0.26200-SP0
# Python version:		 3.12.6 | packaged by conda-forge | (main, Sep 22 2024, 14:01:26) [MSC v.1941 64 bit (AMD64)]
# Date and Time:		 2026-07-10 08:19:30
# cwd:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\user_documents\NfL-PLA Development Paper\NfL-PLA Development Paper Figure Data\GitHub\NfL-iPLA-paper\NfL-iPLA_LoB_AoC
# base_path:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal
# python_folder:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\python
# templates_folder:	 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\templates
# data_folder:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\data
# samples_folder:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\samples
# quality_folder:		 C:\Users\smith.j\OneDrive - wehi.edu.au\Documents\CFHAC_ProxiPal\ProxiPal\quality
# ...

# %%
LoB_AOC = pd.read_csv("LoB_AOC.csv")

# %%
LoB_AOC[['AOC conc','ct']]
# Out:
#     AOC conc      ct
# 0         25  34.489
# 1         25  35.379
# 2         25  37.458
# 3         25     NaN
# 4         25     NaN
# 5         25     NaN
# 6         25  34.874
# 7         25  36.231
# 8        100  31.784
# 9        100  31.815
# 10        25  42.302
# 11        25     NaN
# 12        25  35.145
# 13        25  34.664
# 14        25  34.144
# 15        25  33.516
# 16        25     NaN
# 17        25  35.218
# 18        50  33.512
# 19        50  31.695
# 20        50  33.620
# 21        50  34.924
# 22       100  31.159
# 23       100  30.910
# 24       100  32.353
# 25       100  32.634
# 26        50  32.769
# 27        50  33.828
# 28        50  32.322
# 29        50  32.838
# 30        50  32.863
# 31        50  33.457
# 32        50  33.669
# 33        50  32.825
# 34        50  33.938
# 35        50  32.881

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(88/25.4, 80/25.4))
groups = sorted(LoB_AOC["AOC conc"].unique())
colors = {"25": "#E69F00", "50": "#56B4E9", "100": "#009E73"}

all_vals   = LoB_AOC["ct"].dropna().values
y_max_real = all_vals.max()
gap_bottom = np.ceil(y_max_real) + 0.7
nd_y       = np.ceil(y_max_real) + 1.6

for i, conc in enumerate(groups):
    sub   = LoB_AOC.loc[LoB_AOC["AOC conc"] == conc, "ct"]
    vals  = sub.dropna().values
    n_nd  = int(sub.isna().sum())
    color = colors[str(int(conc))]

    parts = ax.violinplot(vals, positions=[i], widths=0.6,
                          showmedians=True, showextrema=False)
    for pc in parts["bodies"]:
        pc.set_facecolor(color); pc.set_alpha(0.4); pc.set_edgecolor("none")
    parts["cmedians"].set_color("black"); parts["cmedians"].set_linewidth(0.8)

    jitter = np.random.uniform(-0.12, 0.12, size=len(vals))
    ax.scatter(i + jitter, vals, color=color, s=8, alpha=0.8, linewidths=0, zorder=3)

    # if n_nd > 0:
    #     jitter_nd = np.random.uniform(-0.12, 0.12, size=n_nd)
    #     ax.scatter(i + jitter_nd, [nd_y] * n_nd, facecolors="none",
    #                edgecolors=color, s=10, linewidths=0.7, zorder=3)
    #     ax.text(i, nd_y + 0.55, f"n={n_nd}", ha="center", fontsize=5, fontname="sans-serif")

    if n_nd > 0:
        jitter_nd   = np.random.uniform(-0.15, 0.15, size=n_nd)
        y_jitter_nd = np.random.uniform(-0.2, 0.2, size=n_nd)
        ax.scatter(i + jitter_nd, nd_y + y_jitter_nd, facecolors="none",
                   edgecolors=color, s=10, linewidths=0.7, zorder=3)

ax.axhline(gap_bottom, color="grey", linewidth=0.5, linestyle=(0, (2, 2)))
ax.set_ylim(top=nd_y + 1.2)

yticks = [t for t in ax.get_yticks() if t <= y_max_real + 0.5]
yticks.append(nd_y)
ax.set_yticks(yticks)
ax.set_yticklabels([f"{int(t)}" if t != nd_y else "Undet." for t in yticks],
                   fontsize=6, fontname="sans-serif")

ax.set_xticks(range(len(groups)))
ax.set_xticklabels([f"{int(g)} ng/mL" for g in groups], fontsize=6, fontname="sans-serif")
ax.set_ylabel("Cq", fontsize=6, fontname="sans-serif")
ax.set_xlabel("AOC concentration", fontsize=6, fontname="sans-serif")
ax.tick_params(axis="both", labelsize=6)
for spine in ["top", "right"]:
    ax.spines[spine].set_visible(False)
for spine in ["left", "bottom"]:
    ax.spines[spine].set_linewidth(0.6)

plt.tight_layout()
plt.savefig("LoB_AOC_violin.svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
summary = (
    LoB_AOC
    .groupby("AOC conc")["ct"]
    .agg(n_total="size",
         n_detected="count",
         n_undetermined=lambda s: s.isna().sum(),
         mean="mean",
         sd="std")   # pandas default ddof=1 (sample SD) — correct convention here
    .round(2)
)
print(summary)
# Out:
#           n_total  n_detected  n_undetermined   mean    sd
# AOC conc
# 25             16          11               5  35.77  2.41
# 50             14          14               0  33.22  0.79
# 100             6           6               0  31.78  0.66
